# %%
import pandas as pd

data = {
    '이름':['홍길동','유관순','이순신','강감찬','김구','김유신','홍길자','홍길순'],
    '학교':['가산고','가산고','가산고','가산고','가산고','디지털고','디지털고','디지털고'],
    '키':[197,184,168,187,188,202,188,190],
    '국어':[90,40,80,40,15,80,55,100],
    '영어':[85,35,75,60,20,100,65,85],
    '수학':[100,50,70,70,10,95,45,90],
    '과학':[95,55,80,75,35,85,40,95],
    '사회':[85,25,75,80,10,80,35,95],
    'SW특기':['Python','Java','Javascript','','','C','PYTHON','C#']
}

df = pd.DataFrame(data,index = ['1번','2번','3번','4번','5번','6번','7번','8번'])

# %%
df
# Out:
#      이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  홍길동   가산고  197   90   85  100  95  85      Python
# 2번  유관순   가산고  184   40   35   50  55  25        Java
# 3번  이순신   가산고  168   80   75   70  80  75  Javascript
# 4번  강감찬   가산고  187   40   60   70  75  80
# 5번   김구   가산고  188   15   20   10  35  10
# 6번  김유신  디지털고  202   80  100   95  85  80           C
# 7번  홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번  홍길순  디지털고  190  100   85   90  95  95          C#

# %%
# df.index = ['1번','2번','3번','4번','5번','6번','7번','8번']
# df.index.name = '지원번호'
# df

# %%
data = {
   '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
   '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
   '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
   '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}

df = pd.DataFrame(data)
### 영화를 index로 설정해서 역순정렬하시오
df.set_index = "영화"

# %%
# 정렬
# df.sort_index(inplace=True) # 순차정렬
df.sort_index(ascending=False,inplace=True) # 역순정렬
df
# Out:
#    level_0  index         영화  개봉 연도  관객 수    평점
# 7        7      7         명량   2014  1761  8.88
# 6        6      6       극한직업   2019  1626  9.20
# 5        5      5  신과함께-죄와 벌   2017  1441  8.73
# 4        4      4       국제시장   2014  1426  9.16
# 3        3      3         괴물   2006  1301  8.62
# 2        2      2        도둑들   2012  1298  7.64
# 1        1      1    7번방의 선물   2013  1281  8.83
# 0        0      0         암살   2015  1270  9.10

# %%
### 정렬 - 개봉연도 index 지정해서 역순정렬
df.reset_index(inplace=True)   # drop=True 컬럼 삭제됨
df.set_index('개봉 연도',inplace=True)
df.sort_index(ascending=False,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 3
#       1 ### 정렬 - 개봉연도 index 지정해서 역순정렬
#       2 df.reset_index(inplace=True)   # drop=True 컬럼 삭제됨
# ----> 3 df.set_index('개봉 연도',inplace=True)
#       4 df.sort_index(ascending=False,inplace=True)
#       5 df
#
# TypeError: 'str' object is not callable
